# %%
from tensorflow.keras.models import Sequential

# %%
import keras
import tensorflow
import numpy as np
#import keras.src.models
#from tensorflow.keras.src.models import functional

# %%
#versions
import sys
print('python: %s' % sys.version)
print('keras: %s' % keras.__version__)
print('tensorflow: %s' % tensorflow.__version__)

#gogle colab:
#python: 3.10.12 (main, Nov 20 2023, 15:14:05) [GCC 11.4.0]
#keras: 2.15.0
#tensorflow: 2.15.0

#local:
#python: 3.10 .0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]
#keras: 2.13.1
#tensorflow: 2.13.1
# Out:
# python: 3.10.0 (tags/v3.10.0:b494f59, Oct  4 2021, 19:00:18) [MSC v.1929 64 bit (AMD64)]
# keras: 3.4.1
# tensorflow: 2.15.0

# %%
model = keras.models.load_model("model.keras")

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 256, 256,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_pad           │ (None, 262, 262,  │          0 │ input_layer[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1_conv (Conv2D) │ (None, 128, 128,  │      9,472 │ conv1_pad[0][0]   │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# ...

# %%
import numpy as np

from keras_preprocessing import image
from keras_preprocessing.image import ImageDataGenerator

validation_datagen = ImageDataGenerator(rescale = 1./255)

PATH = "tsp-cv/"

WIDTH = 256
HEIGHT = 256

# Load the image
img = image.load_img(PATH + "/0.jpg", target_size=(HEIGHT, WIDTH))

img = image.img_to_array(img)/255
img = np.array([img])
print(img.shape)

# Make a prediction with the model
prediction = model.predict((img))

print(prediction)
# Out:
# (1, 256, 256, 3)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step
# [[72466.484]]

# %%
import pandas as pd

train_data = pd.read_csv('tsp-cv/train.csv')

for i,row in train_data.iterrows():
    print(row['id'], row['filename'], row['distance'])
# Out:
# 0 0.jpg 83110
# 1 1.jpg 1035
# 2 2.jpg 20756
# 3 3.jpg 13286
# 4 4.jpg 13924
# 5 5.jpg 9022
# 6 6.jpg 19379
# 7 7.jpg 19419
# 8 8.jpg 12067
# 9 9.jpg 5976
# 10 10.jpg 4110
# 11 11.jpg 6383
# 12 12.jpg 9055
# 13 13.jpg 11574
# 14 14.jpg 4983
# 15 15.jpg 4758
# 16 16.jpg 12544
# 17 17.jpg 10249
# 18 18.jpg 4819
# 19 19.jpg 8840
# 20 20.jpg 2362
# 21 21.jpg 4526
# 22 22.jpg 39727
# 23 23.jpg 9754
# 24 24.jpg 9129
# 25 25.jpg 14246
# 26 26.jpg 8644
# 27 27.jpg 8839
# 28 28.jpg 4857
# 29 29.jpg 14087
# 30 30.jpg 10131
# 31 31.jpg 8694
# 32 32.jpg 5089
# 33 33.jpg 11670
# 34 34.jpg 112611
# 35 35.jpg 8623
# 36 36.jpg 5084
# 37 37.jpg 8554
# 38 38.jpg 6366
# 39 39.jpg 6215
# 40 40.jpg 5111
# 41 41.jpg 4485
# 42 42.jpg 11999
# 43 43.jpg 62493
# 44 44.jpg 8013
# 45 45.jpg 3863
# 46 46.jpg 8121
# 47 47.jpg 5358
# 48 48.jpg 1955
# 49 49.jpg 6650
# 50 50.jpg 3986
# 51 51.jpg 8237
# 52 52.jpg 14436
# 53 53.jpg 11379
# 54 54.jpg 8562
# 55 55.jpg 5583
# 56 56.jpg 5373
# 57 57.jpg 4900
# ...
